# %% [markdown]
# # Uses images from /eye_left to find gaze coordinates
#
# @author: pawel@kasprowski.pl

# %%
import os
import cv2
import numpy as np

from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, MaxPooling2D, Conv2D
from tensorflow.keras.models import Sequential

# %% [markdown]
# # Loads all images from /indir
# ### label is derived from file name

# %%
def load_images(indir):
    samples = []
    labels = []
    for imagePath in os.listdir(indir):
        image = cv2.imread("{}/{}".format(indir,imagePath))
        image = preprocess(image)
        samples.append(image)
        label = np.zeros((2))
        label[0] = float(imagePath[0:imagePath.find("_")])
        label[1] = float(imagePath[imagePath.find("_")+1:imagePath.find(".")])
        labels.append(label)
    samples = np.array(samples, dtype="float")
    labels = np.array(labels)
    return samples,labels

# %% [markdown]
# ## Resize each image to (64,64) and then mask the image with ellipse

# %%
def preprocess(image):
    image = cv2.resize(image, (64, 64))
    mask = np.zeros_like(image)
    cols, rows,_ = mask.shape
    mask=cv2.ellipse(mask, center=(rows//2, cols//2), axes=(28,14), 
                     angle=0, startAngle=0, endAngle=360, 
                     color=(255,255,255), thickness=-1)
    result = np.bitwise_and(image,mask)
    result = result[14:64-14,:]
    return result

# %%
print("Loading images...")
samples,labels = load_images("eye_left")
print(samples.shape)
# Out:
# Loading images...
# (200, 36, 64, 3)

# %% [markdown]
# ## Build the model

# %%
def build_cnn_model():
    model = Sequential()
    model.add(Conv2D(32, (7, 7), padding="same",input_shape=(36,64,3)))
    model.add(Activation("relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Conv2D(64, (5, 5), padding="same"))
    model.add(Activation("relu"))
    
    model.add(Conv2D(64, (5, 5), padding="same"))
    model.add(Activation("relu"))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation("relu"))
    #model.add(Dropout(0.5))
    model.add(Dense(2)) # two values X,Y
    return model

model = build_cnn_model()
model.compile(loss="mean_absolute_error", optimizer="adam", metrics=["mae"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 36, 64, 32)        4736
# _________________________________________________________________
# activation (Activation)      (None, 36, 64, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 18, 32, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 18, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 32, 64)        51264
# _________________________________________________________________
# activation_1 (Activation)    (None, 18, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 18, 32, 64)        102464
# _________________________________________________________________
# activation_2 (Activation)    (None, 18, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 16, 64)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 16, 64)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               4719104
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 4,878,594
# Trainable params: 4,878,594
# Non-trainable params: 0
# _________________________________________________________________

# %%
(trainSamples, testSamples, trainLabels, testLabels) = train_test_split(samples, labels, test_size=0.15, random_state=42)

checkpt1 = ModelCheckpoint(filepath='models/model.{epoch:02d}-{val_loss:.2f}.h5', save_best_only=True)

# train
EPOCHS = 100
for e in range(EPOCHS):
    print("=" * 50)
    print("Iteration: {}".format(e))
    H = model.fit(trainSamples, trainLabels, validation_data=(testSamples, testLabels), epochs=1, batch_size=32, verbose=0,
                  callbacks=[checkpt1])
                  
    #print(H.history)              
    print("Error so far: {}".format(H.history["val_mae"]))

    predictions = model.predict(testSamples, batch_size=32)
    results = np.zeros((800,1500,3))
    dx = 0
    dy = 0
    # create an image with current predictions
    for i in range(testSamples.shape[0]):
        cv2.circle(results,(int(testLabels[i,0]),int(testLabels[i,1])),10,(0,255,0),3) # true gaze points
        cv2.circle(results,(int(predictions[i,0]),int(predictions[i,1])),10,(255,0,0),3) # predicted gaze point
        cv2.line(results, 
                 (int(predictions[i,0]),int(predictions[i,1])), # line connecting ground truth with prediction
                 (int(testLabels[i,0]),int(testLabels[i,1])), 
                 (255,0,0),3
                 )
        dx = dx + abs(testLabels[i,0] - predictions[i,0])
        dy = dy + abs(testLabels[i,1] - predictions[i,1])
        
    dx = dx/testSamples.shape[0]
    dy = dy/testSamples.shape[0]
        
    cv2.putText(results,"ErrX: {0:.0f}".format(dx),(10,30),cv2.FONT_HERSHEY_SIMPLEX,0.8,(255,255,255),2)    
    cv2.putText(results,"ErrY: {0:.0f}".format(dy),(10,60),cv2.FONT_HERSHEY_SIMPLEX,0.8,(255,255,255),2)    
    cv2.imwrite("img/test_{:02d}.jpg".format(e),results)
 
print("Final MAE: {}".format(mean_absolute_error(testLabels,predictions)))    

model.save("final_model_{0:.2f}.h5".format(mean_absolute_error(testLabels,predictions)))
# Out:
# ==================================================
# Iteration: 0
# Error so far: [369.35577392578125]
# ==================================================
# Iteration: 1
# Error so far: [279.1451416015625]
# ==================================================
# Iteration: 2
# Error so far: [277.65045166015625]
# ==================================================
# Iteration: 3
# Error so far: [280.9859619140625]
# ==================================================
# Iteration: 4
# Error so far: [295.71075439453125]
# ==================================================
# Iteration: 5
# Error so far: [285.8829345703125]
# ==================================================
# Iteration: 6
# Error so far: [282.0226745605469]
# ==================================================
# Iteration: 7
# Error so far: [280.05010986328125]
# ==================================================
# Iteration: 8
# Error so far: [290.0069885253906]
# ==================================================
# Iteration: 9
# Error so far: [282.9042663574219]
# ==================================================
# Iteration: 10
# Error so far: [281.34442138671875]
# ==================================================
# Iteration: 11
# Error so far: [276.9781799316406]
# ==================================================
# Iteration: 12
# Error so far: [247.73056030273438]
# ==================================================
# Iteration: 13
# Error so far: [218.7707977294922]
# ==================================================
# Iteration: 14
# Error so far: [122.1396484375]
# ==================================================
# Iteration: 15
# Error so far: [159.17880249023438]
# ==================================================
# Iteration: 16
# Error so far: [123.68216705322266]
# ==================================================
# Iteration: 17
# Error so far: [113.56864166259766]
# ==================================================
# Iteration: 18
# Error so far: [165.24191284179688]
# ==================================================
# Iteration: 19
# Error so far: [128.67550659179688]
# ==================================================
# Iteration: 20
# Error so far: [83.46619415283203]
# ==================================================
# Iteration: 21
# Error so far: [74.01681518554688]
# ==================================================
# Iteration: 22
# Error so far: [93.90802764892578]
# ==================================================
# Iteration: 23
# Error so far: [89.64386749267578]
# ==================================================
# Iteration: 24
# Error so far: [112.7535171508789]
# ==================================================
# Iteration: 25
# Error so far: [77.171630859375]
# ==================================================
# Iteration: 26
# Error so far: [83.62522888183594]
# ==================================================
# Iteration: 27
# Error so far: [85.03585815429688]
# ==================================================
# Iteration: 28
# Error so far: [59.52621841430664]
# ==================================================
# Iteration: 29
# Error so far: [65.16421508789062]
# ==================================================
# Iteration: 30
# Error so far: [70.33448791503906]
# ==================================================
# Iteration: 31
# Error so far: [61.226932525634766]
# ==================================================
# Iteration: 32
# Error so far: [63.60435104370117]
# ==================================================
# Iteration: 33
# Error so far: [66.13066101074219]
# ==================================================
# Iteration: 34
# Error so far: [75.98585510253906]
# ==================================================
# Iteration: 35
# Error so far: [56.9805793762207]
# ==================================================
# Iteration: 36
# Error so far: [137.2523956298828]
# ==================================================
# Iteration: 37
# Error so far: [62.008628845214844]
# ==================================================
# Iteration: 38
# Error so far: [109.3095703125]
# ==================================================
# Iteration: 39
# Error so far: [70.46697235107422]
# ==================================================
# Iteration: 40
# Error so far: [87.30177307128906]
# ==================================================
# Iteration: 41
# Error so far: [57.88272476196289]
# ==================================================
# Iteration: 42
# Error so far: [55.3678092956543]
# ==================================================
# Iteration: 43
# Error so far: [62.616905212402344]
# ==================================================
# Iteration: 44
# Error so far: [52.741722106933594]
# ==================================================
# Iteration: 45
# Error so far: [51.61347961425781]
# ==================================================
# Iteration: 46
# Error so far: [73.46926879882812]
# ==================================================
# Iteration: 47
# Error so far: [55.649513244628906]
# ==================================================
# Iteration: 48
# Error so far: [52.56398010253906]
# ==================================================
# Iteration: 49
# Error so far: [56.65375900268555]
# ==================================================
# Iteration: 50
# Error so far: [62.7838249206543]
# ==================================================
# Iteration: 51
# Error so far: [56.23305892944336]
# ==================================================
# Iteration: 52
# Error so far: [83.41714477539062]
# ==================================================
# Iteration: 53
# Error so far: [65.03939056396484]
# ==================================================
# Iteration: 54
# Error so far: [55.07661056518555]
# ==================================================
# Iteration: 55
# Error so far: [52.00481033325195]
# ==================================================
# Iteration: 56
# Error so far: [65.4661636352539]
# ==================================================
# Iteration: 57
# Error so far: [108.2502670288086]
# ==================================================
# Iteration: 58
# Error so far: [62.487525939941406]
# ==================================================
# Iteration: 59
# Error so far: [79.43344116210938]
# ==================================================
# Iteration: 60
# Error so far: [63.396671295166016]
# ==================================================
# Iteration: 61
# Error so far: [53.79258346557617]
# ==================================================
# Iteration: 62
# Error so far: [89.97679901123047]
# ==================================================
# Iteration: 63
# Error so far: [95.58527374267578]
# ==================================================
# Iteration: 64
# Error so far: [60.972206115722656]
# ==================================================
# Iteration: 65
# Error so far: [53.2689094543457]
# ==================================================
# Iteration: 66
# Error so far: [48.42605209350586]
# ==================================================
# Iteration: 67
# Error so far: [61.77778244018555]
# ==================================================
# Iteration: 68
# Error so far: [75.30728912353516]
# ==================================================
# Iteration: 69
# Error so far: [56.46739196777344]
# ==================================================
# Iteration: 70
# Error so far: [44.934814453125]
# ==================================================
# Iteration: 71
# Error so far: [56.132503509521484]
# ==================================================
# Iteration: 72
# Error so far: [60.33525466918945]
# ==================================================
# Iteration: 73
# Error so far: [48.48903274536133]
# ==================================================
# Iteration: 74
# Error so far: [79.8707275390625]
# ==================================================
# Iteration: 75
# Error so far: [68.71117401123047]
# ==================================================
# Iteration: 76
# Error so far: [59.53689193725586]
# ==================================================
# Iteration: 77
# Error so far: [50.06868362426758]
# ==================================================
# Iteration: 78
# Error so far: [47.124061584472656]
# ==================================================
# Iteration: 79
# Error so far: [52.73540496826172]
# ==================================================
# Iteration: 80
# Error so far: [45.23910140991211]
# ==================================================
# Iteration: 81
# Error so far: [53.2660026550293]
# ==================================================
# Iteration: 82
# Error so far: [44.67348098754883]
# ==================================================
# Iteration: 83
# Error so far: [53.3012580871582]
# ==================================================
# Iteration: 84
# Error so far: [48.90850067138672]
# ==================================================
# Iteration: 85
# Error so far: [49.03639602661133]
# ==================================================
# Iteration: 86
# Error so far: [59.20870590209961]
# ==================================================
# Iteration: 87
# Error so far: [45.26564407348633]
# ==================================================
# Iteration: 88
# Error so far: [53.10991668701172]
# ==================================================
# Iteration: 89
# Error so far: [50.09770965576172]
# ==================================================
# Iteration: 90
# Error so far: [50.72364807128906]
# ==================================================
# Iteration: 91
# Error so far: [49.39659881591797]
# ==================================================
# Iteration: 92
# Error so far: [50.396915435791016]
# ==================================================
# Iteration: 93
# Error so far: [45.89722442626953]
# ==================================================
# Iteration: 94
# Error so far: [56.496986389160156]
# ==================================================
# Iteration: 95
# Error so far: [48.152286529541016]
# ==================================================
# Iteration: 96
# Error so far: [43.384830474853516]
# ==================================================
# Iteration: 97
# Error so far: [85.057373046875]
# ==================================================
# Iteration: 98
# Error so far: [64.74891662597656]
# ==================================================
# Iteration: 99
# Error so far: [61.12353515625]
# Final MAE: 61.123537445068365
